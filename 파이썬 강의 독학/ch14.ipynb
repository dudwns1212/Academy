# %%
# %matplotlib inline
# 한글 깨짐 해결 코드
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font', family='Malgun Gothic')

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('systolic.csv')
df.plot()  # df.plot(kind='line')
plt.show()

# %%
df2 = df.iloc[[0,1,2], 8:]
df2.index = ['이겨레', '조약돌', '강산애']
df2
# Out:
#       1차   2차   3차   4차   5차
# 이겨레  120  125  128  118  120
# 조약돌  119  121  119  124  119
# 강산애  135  139  136  150  137

# %%
df2.plot(kind='bar', figsize=(12,4))
plt.xticks(rotation=0)
plt.show()

# %%
df2 = df.iloc[[0,1,2], 5:8]
df2.index = ['이겨레', '조약돌', '강산애']
df2
# Out:
#        키  체중    BMI
# 이겨레  181  76  23.20
# 조약돌  185  89  26.00
# 강산애  177  63  20.11

# %%
df2.plot(kind='barh', figsize=(6,4))
plt.show()

# %%
df
# Out:
#       환자코드   이름 성별  연령 혈액형    키  체중    BMI   1차   2차   3차   4차   5차
# 0  P330531  이겨레  남  26   A  181  76  23.20  120  125  128  118  120
# 1  P340037  조약돌  여  25   B  185  89  26.00  119  121  119  124  119
# 2  P194563  강산애  남  27   A  177  63  20.11  135  139  136  150  137
# 3  P503546  원미연  여  48   O  166  55  19.96  143  152  153  149  144
# 4  P330543  오대양  남  31  AB  193  95  25.50  120  123  118  120  122
# 5  P341257  송가인  여  45   O  157  48  19.47  138  138  139  142  148
# 6  P472358  성공찬  여  53   B  159  50  19.78  157  153  148  145  137
# 7  P185823  황산성  남  52   B  178  87  27.46  159  159  162  163  169
# 8  P232305  신영웅  남  19  AB  163  53  19.95  121  124  125  108  110
# 9  P489602  최고봉  남  64   A  168  57  20.20  153  149  144  162  153

# %%
df2 = df.iloc[[0,1,2], 8:]
df2.index = ['이겨레', '조약돌', '강산애']
df2
# Out:
#       1차   2차   3차   4차   5차
# 이겨레  120  125  128  118  120
# 조약돌  119  121  119  124  119
# 강산애  135  139  136  150  137

# %%
df2.plot(kind='box')
plt.show()

# %%
df2 = df.iloc[[0,1,2], 8:]
df2.index = ['이겨레', '조약돌', '강산애']
df2
# Out:
#       1차   2차   3차   4차   5차
# 이겨레  120  125  128  118  120
# 조약돌  119  121  119  124  119
# 강산애  135  139  136  150  137

# %%
df2.plot(kind='kde')
plt.show()

# %%
df2.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# end
